# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\cmrit\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\cmrit\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\cmrit\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\cmrit\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\cmrit\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\cmrit\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.tokenize import word_tokenize as wt
from nltk.probability import FreqDist as fd
from nltk.corpus import stopwords as sw

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cmrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\cmrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def word_analysis(text):
     words = wt(text)
     words = [word.lower() for word in words if word.isalpha()]
     stop_words = set(sw.words('english'))
     words = [word for word in words if word not in stop_words]
     freq_dist = fd(words)
     most_common_words = freq_dist.most_common(10)  
     print("total words",len(words))
     print("unique words",len(freq_dist))
     print("Most common words:", most_common_words)

# %%
Text=input("Enter text:")
word_analysis(Text)
# Out:
# Enter text: give a paragraph of 20 words like a poem or text or something past any sentence
# total words 9
# unique words 9
# Most common words: [('give', 1), ('paragraph', 1), ('words', 1), ('like', 1), ('poem', 1), ('text', 1), ('something', 1), ('past', 1), ('sentence', 1)]
