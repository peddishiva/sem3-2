# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
import random
nltk.download('stopwords')
nltk.download('punkt_tab')
def generate_words(text, num_words):
    words = word_tokenize(text.lower()) 
    stop_words = set(stopwords.words('english')) 
    words = [word for word in words if word.isalnum() and word not in stop_words] 
    generated_words = [] 
    for _ in range(num_words):
      generated_words.append(random.choice(words))
    return generated_words
text = input("Enter Text: ")
generated_words = generate_words(text, num_words=5)
print("Generated Words::", generated_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Enter Text:  hi
# Generated Words:: ['hi', 'hi', 'hi', 'hi', 'hi']

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
import random

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def generate_words(text, num_words):
    words = word_tokenize(text.lower()) 
    stop_words = set(stopwords.words('english')) 
    words = [word for word in words if word.isalnum() and word not in stop_words] 
    generated_words = [] 
    for _ in range(num_words):
      generated_words.append(random.choice(words))
    return generated_words

# %%
text = input("Enter Text: ")
generated_words = generate_words(text, num_words=5)
print("Generated Words::", generated_words)
# Out:
# Enter Text:  After a long and arduous journey, the weary travelers finally reached the majestic city, greeted by cheering crowds and festive music.
# Generated Words:: ['finally', 'greeted', 'city', 'music', 'finally']
